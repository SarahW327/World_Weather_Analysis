# %% [markdown]
# ## Deliverable 1

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count += 1

     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | p
# Processing Record 2 of the Set 1 | r
# Processing Record 3 of the Set 1 | p
# Processing Record 4 of the Set 1 | s
# Processing Record 5 of the Set 1 | b
# Processing Record 6 of the Set 1 | r
# Processing Record 7 of the Set 1 | k
# Processing Record 8 of the Set 1 | v
# Processing Record 9 of the Set 1 | a
# Processing Record 10 of the Set 1 | m
# Processing Record 11 of the Set 1 | m
# Processing Record 12 of the Set 1 | s
# Processing Record 13 of the Set 1 | c
# Processing Record 14 of the Set 1 | h
# Processing Record 15 of the Set 1 | y
# Processing Record 16 of the Set 1 | a
# Processing Record 17 of the Set 1 | t
# City not found. Skipping...
# Processing Record 18 of the Set 1 | g
# Processing Record 19 of the Set 1 | b
# Processing Record 20 of the Set 1 | s
# Processing Record 21 of the Set 1 | s
# Processing Record 22 of the Set 1 | t
# Processing Record 23 of the Set 1 | t
# Processing Record 24 of the Set 1 | m
# City not found. Skipping...
# Processing Record 25 of the Set 1 | c
# Processing Record 26 of the Set 1 | t
# Processing Record 27 of the Set 1 | f
# Processing Record 28 of the Set 1 | a
# Processing Record 29 of the Set 1 | k
# Processing Record 30 of the Set 1 | h
# Processing Record 31 of the Set 1 | z
# Processing Record 32 of the Set 1 | p
# Processing Record 33 of the Set 1 | b
# Processing Record 34 of the Set 1 | k
# Processing Record 35 of the Set 1 | w
# Processing Record 36 of the Set 1 | y
# Processing Record 37 of the Set 1 | n
# Processing Record 38 of the Set 1 | a
# Processing Record 39 of the Set 1 | f
# Processing Record 40 of the Set 1 | j
# Processing Record 41 of the Set 1 | d
# Processing Record 42 of the Set 1 | a
# Processing Record 43 of the Set 1 | b
# Processing Record 44 of the Set 1 | v
# Processing Record 45 of the Set 1 | m
# Processing Record 46 of the Set 1 | r
# Processing Record 47 of the Set 1 | t
# Processing Record 48 of the Set 1 | f
# Processing Record 49 of the Set 1 | c
# Processing Record 50 of the Set 1 | t
# City not found. Skipping...
# Processing Record 1 of the Set 2 | c
# Processing Record 2 of the Set 2 | i
# Processing Record 3 of the Set 2 | q
# Processing Record 4 of the Set 2 | m
# Processing Record 5 of the Set 2 | m
# Processing Record 6 of the Set 2 | k
# Processing Record 7 of the Set 2 | e
# Processing Record 8 of the Set 2 | j
# City not found. Skipping...
# Processing Record 9 of the Set 2 | u
# City not found. Skipping...
# Processing Record 10 of the Set 2 | k
# Processing Record 11 of the Set 2 | b
# Processing Record 12 of the Set 2 | v
# Processing Record 13 of the Set 2 | m
# Processing Record 14 of the Set 2 | s
# Processing Record 15 of the Set 2 | c
# Processing Record 16 of the Set 2 | n
# Processing Record 17 of the Set 2 | d
# Processing Record 18 of the Set 2 | b
# Processing Record 19 of the Set 2 | i
# City not found. Skipping...
# Processing Record 20 of the Set 2 | g
# Processing Record 21 of the Set 2 | n
# Processing Record 22 of the Set 2 | a
# Processing Record 23 of the Set 2 | c
# Processing Record 24 of the Set 2 | d
# Processing Record 25 of the Set 2 | a
# Processing Record 26 of the Set 2 | c
# Processing Record 27 of the Set 2 | o
# City not found. Skipping...
# Processing Record 28 of the Set 2 | b
# Processing Record 29 of the Set 2 | y
# City not found. Skipping...
# Processing Record 30 of the Set 2 | s
# Processing Record 31 of the Set 2 | a
# Processing Record 32 of the Set 2 | s
# Processing Record 33 of the Set 2 | u
# Processing Record 34 of the Set 2 | r
# City not found. Skipping...
# Processing Record 35 of the Set 2 | s
# Processing Record 36 of the Set 2 | s
# Processing Record 37 of the Set 2 | l
# Processing Record 38 of the Set 2 | b
# Processing Record 39 of the Set 2 | p
# Processing Record 40 of the Set 2 | f
# Processing Record 41 of the Set 2 | t
# Processing Record 42 of the Set 2 | p
# Processing Record 43 of the Set 2 | a
# City not found. Skipping...
# Processing Record 44 of the Set 2 | p
# Processing Record 45 of the Set 2 | d
# Processing Record 46 of the Set 2 | f
# Processing Record 47 of the Set 2 | p
# Processing Record 48 of the Set 2 | w
# Processing Record 49 of the Set 2 | u
# Processing Record 50 of the Set 2 | d
# Processing Record 1 of the Set 3 | c
# Processing Record 2 of the Set 3 | b
# Processing Record 3 of the Set 3 | t
# Processing Record 4 of the Set 3 | s
# Processing Record 5 of the Set 3 | y
# Processing Record 6 of the Set 3 | t
# Processing Record 7 of the Set 3 | p
# Processing Record 8 of the Set 3 | p
# Processing Record 9 of the Set 3 | n
# Processing Record 10 of the Set 3 | t
# Processing Record 11 of the Set 3 | n
# Processing Record 12 of the Set 3 | h
# Processing Record 13 of the Set 3 | t
# Processing Record 14 of the Set 3 | c
# Processing Record 15 of the Set 3 | p
# Processing Record 16 of the Set 3 | l
# Processing Record 17 of the Set 3 | h
# Processing Record 18 of the Set 3 | n
# Processing Record 19 of the Set 3 | b
# Processing Record 20 of the Set 3 | k
# Processing Record 21 of the Set 3 | g
# Processing Record 22 of the Set 3 | s
# Processing Record 23 of the Set 3 | k
# Processing Record 24 of the Set 3 | s
# Processing Record 25 of the Set 3 | d
# Processing Record 26 of the Set 3 | u
# Processing Record 27 of the Set 3 | d
# Processing Record 28 of the Set 3 | t
# Processing Record 29 of the Set 3 | a
# Processing Record 30 of the Set 3 | j
# Processing Record 31 of the Set 3 | m
# Processing Record 32 of the Set 3 | z
# Processing Record 33 of the Set 3 | h
# Processing Record 34 of the Set 3 | p
# Processing Record 35 of the Set 3 | e
# Processing Record 36 of the Set 3 | s
# Processing Record 37 of the Set 3 | h
# Processing Record 38 of the Set 3 | b
# Processing Record 39 of the Set 3 | l
# Processing Record 40 of the Set 3 | r
# Processing Record 41 of the Set 3 | y
# Processing Record 42 of the Set 3 | w
# Processing Record 43 of the Set 3 | n
# Processing Record 44 of the Set 3 | l
# Processing Record 45 of the Set 3 | j
# Processing Record 46 of the Set 3 | p
# Processing Record 47 of the Set 3 | u
# Processing Record 48 of the Set 3 | w
# Processing Record 49 of the Set 3 | s
# Processing Record 50 of the Set 3 | l
# Processing Record 1 of the Set 4 | c
# Processing Record 2 of the Set 4 | j
# Processing Record 3 of the Set 4 | t
# Processing Record 4 of the Set 4 | b
# Processing Record 5 of the Set 4 | p
# Processing Record 6 of the Set 4 | r
# Processing Record 7 of the Set 4 | g
# City not found. Skipping...
# Processing Record 8 of the Set 4 | t
# Processing Record 9 of the Set 4 | c
# Processing Record 10 of the Set 4 | a
# Processing Record 11 of the Set 4 | m
# Processing Record 12 of the Set 4 | w
# Processing Record 13 of the Set 4 | e
# Processing Record 14 of the Set 4 | b
# Processing Record 15 of the Set 4 | t
# Processing Record 16 of the Set 4 | o
# Processing Record 17 of the Set 4 | p
# Processing Record 18 of the Set 4 | c
# Processing Record 19 of the Set 4 | n
# Processing Record 20 of the Set 4 | e
# Processing Record 21 of the Set 4 | b
# City not found. Skipping...
# Processing Record 22 of the Set 4 | k
# Processing Record 23 of the Set 4 | k
# Processing Record 24 of the Set 4 | v
# City not found. Skipping...
# Processing Record 25 of the Set 4 | t
# Processing Record 26 of the Set 4 | t
# Processing Record 27 of the Set 4 | s
# Processing Record 28 of the Set 4 | a
# City not found. Skipping...
# Processing Record 29 of the Set 4 | k
# Processing Record 30 of the Set 4 | m
# Processing Record 31 of the Set 4 | m
# Processing Record 32 of the Set 4 | b
# Processing Record 33 of the Set 4 | s
# Processing Record 34 of the Set 4 | h
# Processing Record 35 of the Set 4 | v
# Processing Record 36 of the Set 4 | v
# Processing Record 37 of the Set 4 | p
# Processing Record 38 of the Set 4 | m
# Processing Record 39 of the Set 4 | v
# Processing Record 40 of the Set 4 | m
# Processing Record 41 of the Set 4 | n
# Processing Record 42 of the Set 4 | n
# Processing Record 43 of the Set 4 | b
# Processing Record 44 of the Set 4 | s
# City not found. Skipping...
# Processing Record 45 of the Set 4 | h
# Processing Record 46 of the Set 4 | h
# Processing Record 47 of the Set 4 | l
# Processing Record 48 of the Set 4 | j
# Processing Record 49 of the Set 4 | a
# Processing Record 50 of the Set 4 | z
# Processing Record 1 of the Set 5 | l
# Processing Record 2 of the Set 5 | o
# Processing Record 3 of the Set 5 | b
# Processing Record 4 of the Set 5 | c
# Processing Record 5 of the Set 5 | s
# Processing Record 6 of the Set 5 | k
# Processing Record 7 of the Set 5 | p
# Processing Record 8 of the Set 5 | g
# Processing Record 9 of the Set 5 | h
# Processing Record 10 of the Set 5 | p
# Processing Record 11 of the Set 5 | a
# Processing Record 12 of the Set 5 | n
# City not found. Skipping...
# Processing Record 13 of the Set 5 | k
# Processing Record 14 of the Set 5 | m
# Processing Record 15 of the Set 5 | a
# City not found. Skipping...
# Processing Record 16 of the Set 5 | e
# Processing Record 17 of the Set 5 | m
# Processing Record 18 of the Set 5 | c
# Processing Record 19 of the Set 5 | m
# Processing Record 20 of the Set 5 | g
# Processing Record 21 of the Set 5 | m
# Processing Record 22 of the Set 5 | l
# Processing Record 23 of the Set 5 | u
# Processing Record 24 of the Set 5 | a
# Processing Record 25 of the Set 5 | s
# Processing Record 26 of the Set 5 | i
# Processing Record 27 of the Set 5 | k
# Processing Record 28 of the Set 5 | t
# Processing Record 29 of the Set 5 | p
# Processing Record 30 of the Set 5 | p
# City not found. Skipping...
# Processing Record 31 of the Set 5 | l
# City not found. Skipping...
# Processing Record 32 of the Set 5 | f
# Processing Record 33 of the Set 5 | b
# Processing Record 34 of the Set 5 | a
# Processing Record 35 of the Set 5 | c
# City not found. Skipping...
# Processing Record 36 of the Set 5 | k
# Processing Record 37 of the Set 5 | m
# Processing Record 38 of the Set 5 | a
# Processing Record 39 of the Set 5 | p
# Processing Record 40 of the Set 5 | a
# Processing Record 41 of the Set 5 | a
# Processing Record 42 of the Set 5 | m
# Processing Record 43 of the Set 5 | k
# Processing Record 44 of the Set 5 | h
# Processing Record 45 of the Set 5 | h
# Processing Record 46 of the Set 5 | h
# Processing Record 47 of the Set 5 | a
# Processing Record 48 of the Set 5 | g
# Processing Record 49 of the Set 5 | l
# Processing Record 50 of the Set 5 | b
# Processing Record 1 of the Set 6 | h
# Processing Record 2 of the Set 6 | k
# Processing Record 3 of the Set 6 | s
# Processing Record 4 of the Set 6 | p
# City not found. Skipping...
# Processing Record 5 of the Set 6 | n
# Processing Record 6 of the Set 6 | t
# City not found. Skipping...
# Processing Record 7 of the Set 6 | t
# City not found. Skipping...
# Processing Record 8 of the Set 6 | t
# Processing Record 9 of the Set 6 | m
# City not found. Skipping...
# Processing Record 10 of the Set 6 | c
# Processing Record 11 of the Set 6 | z
# Processing Record 12 of the Set 6 | m
# Processing Record 13 of the Set 6 | n
# Processing Record 14 of the Set 6 | d
# Processing Record 15 of the Set 6 | f
# Processing Record 16 of the Set 6 | b
# Processing Record 17 of the Set 6 | d
# Processing Record 18 of the Set 6 | p
# Processing Record 19 of the Set 6 | c
# Processing Record 20 of the Set 6 | n
# Processing Record 21 of the Set 6 | b
# Processing Record 22 of the Set 6 | h
# Processing Record 23 of the Set 6 | w
# Processing Record 24 of the Set 6 | v
# Processing Record 25 of the Set 6 | b
# Processing Record 26 of the Set 6 | m
# Processing Record 27 of the Set 6 | w
# Processing Record 28 of the Set 6 | k
# Processing Record 29 of the Set 6 | i
# Processing Record 30 of the Set 6 | b
# Processing Record 31 of the Set 6 | a
# Processing Record 32 of the Set 6 | r
# Processing Record 33 of the Set 6 | e
# Processing Record 34 of the Set 6 | a
# Processing Record 35 of the Set 6 | t
# Processing Record 36 of the Set 6 | b
# Processing Record 37 of the Set 6 | j
# Processing Record 38 of the Set 6 | p
# Processing Record 39 of the Set 6 | c
# Processing Record 40 of the Set 6 | l
# Processing Record 41 of the Set 6 | g
# Processing Record 42 of the Set 6 | b
# Processing Record 43 of the Set 6 | r
# Processing Record 44 of the Set 6 | v
# Processing Record 45 of the Set 6 | k
# Processing Record 46 of the Set 6 | v
# Processing Record 47 of the Set 6 | t
# Processing Record 48 of the Set 6 | b
# Processing Record 49 of the Set 6 | i
# Processing Record 50 of the Set 6 | k
# Processing Record 1 of the Set 7 | r
# Processing Record 2 of the Set 7 | k
# Processing Record 3 of the Set 7 | s
# Processing Record 4 of the Set 7 | d
# Processing Record 5 of the Set 7 | l
# Processing Record 6 of the Set 7 | o
# Processing Record 7 of the Set 7 | r
# Processing Record 8 of the Set 7 | m
# Processing Record 9 of the Set 7 | f
# Processing Record 10 of the Set 7 | s
# Processing Record 11 of the Set 7 | l
# Processing Record 12 of the Set 7 | s
# Processing Record 13 of the Set 7 | a
# Processing Record 14 of the Set 7 | d
# Processing Record 15 of the Set 7 | w
# Processing Record 16 of the Set 7 | m
# Processing Record 17 of the Set 7 | b
# Processing Record 18 of the Set 7 | p
# Processing Record 19 of the Set 7 | b
# City not found. Skipping...
# Processing Record 20 of the Set 7 | w
# Processing Record 21 of the Set 7 | p
# Processing Record 22 of the Set 7 | m
# City not found. Skipping...
# Processing Record 23 of the Set 7 | s
# Processing Record 24 of the Set 7 | j
# Processing Record 25 of the Set 7 | i
# Processing Record 26 of the Set 7 | m
# Processing Record 27 of the Set 7 | d
# Processing Record 28 of the Set 7 | p
# Processing Record 29 of the Set 7 | c
# Processing Record 30 of the Set 7 | q
# Processing Record 31 of the Set 7 | v
# Processing Record 32 of the Set 7 | p
# Processing Record 33 of the Set 7 | c
# Processing Record 34 of the Set 7 | h
# Processing Record 35 of the Set 7 | x
# Processing Record 36 of the Set 7 | t
# Processing Record 37 of the Set 7 | a
# Processing Record 38 of the Set 7 | k
# Processing Record 39 of the Set 7 | c
# Processing Record 40 of the Set 7 | p
# Processing Record 41 of the Set 7 | t
# Processing Record 42 of the Set 7 | p
# Processing Record 43 of the Set 7 | t
# Processing Record 44 of the Set 7 | s
# Processing Record 45 of the Set 7 | n
# Processing Record 46 of the Set 7 | k
# Processing Record 47 of the Set 7 | i
# Processing Record 48 of the Set 7 | z
# Processing Record 49 of the Set 7 | k
# Processing Record 50 of the Set 7 | s
# Processing Record 1 of the Set 8 | q
# Processing Record 2 of the Set 8 | b
# City not found. Skipping...
# Processing Record 3 of the Set 8 | s
# Processing Record 4 of the Set 8 | h
# Processing Record 5 of the Set 8 | d
# Processing Record 6 of the Set 8 | u
# Processing Record 7 of the Set 8 | k
# Processing Record 8 of the Set 8 | k
# City not found. Skipping...
# Processing Record 9 of the Set 8 | v
# Processing Record 10 of the Set 8 | a
# Processing Record 11 of the Set 8 | m
# City not found. Skipping...
# Processing Record 12 of the Set 8 | p
# Processing Record 13 of the Set 8 | i
# Processing Record 14 of the Set 8 | c
# Processing Record 15 of the Set 8 | a
# Processing Record 16 of the Set 8 | k
# Processing Record 17 of the Set 8 | m
# Processing Record 18 of the Set 8 | a
# Processing Record 19 of the Set 8 | s
# City not found. Skipping...
# Processing Record 20 of the Set 8 | l
# Processing Record 21 of the Set 8 | s
# Processing Record 22 of the Set 8 | c
# Processing Record 23 of the Set 8 | m
# Processing Record 24 of the Set 8 | f
# Processing Record 25 of the Set 8 | k
# Processing Record 26 of the Set 8 | b
# Processing Record 27 of the Set 8 | m
# Processing Record 28 of the Set 8 | m
# Processing Record 29 of the Set 8 | p
# Processing Record 30 of the Set 8 | i
# City not found. Skipping...
# Processing Record 31 of the Set 8 | y
# Processing Record 32 of the Set 8 | s
# Processing Record 33 of the Set 8 | g
# Processing Record 34 of the Set 8 | c
# Processing Record 35 of the Set 8 | m
# Processing Record 36 of the Set 8 | l
# Processing Record 37 of the Set 8 | a
# Processing Record 38 of the Set 8 | k
# Processing Record 39 of the Set 8 | b
# Processing Record 40 of the Set 8 | t
# Processing Record 41 of the Set 8 | t
# Processing Record 42 of the Set 8 | a
# Processing Record 43 of the Set 8 | s
# Processing Record 44 of the Set 8 | p
# Processing Record 45 of the Set 8 | v
# Processing Record 46 of the Set 8 | s
# Processing Record 47 of the Set 8 | c
# Processing Record 48 of the Set 8 | n
# Processing Record 49 of the Set 8 | m
# Processing Record 50 of the Set 8 | a
# Processing Record 1 of the Set 9 | x
# Processing Record 2 of the Set 9 | r
# Processing Record 3 of the Set 9 | m
# Processing Record 4 of the Set 9 | l
# City not found. Skipping...
# Processing Record 5 of the Set 9 | s
# Processing Record 6 of the Set 9 | y
# Processing Record 7 of the Set 9 | m
# Processing Record 8 of the Set 9 | m
# Processing Record 9 of the Set 9 | m
# Processing Record 10 of the Set 9 | k
# Processing Record 11 of the Set 9 | h
# City not found. Skipping...
# Processing Record 12 of the Set 9 | n
# Processing Record 13 of the Set 9 | v
# Processing Record 14 of the Set 9 | m
# Processing Record 15 of the Set 9 | s
# Processing Record 16 of the Set 9 | b
# Processing Record 17 of the Set 9 | l
# Processing Record 18 of the Set 9 | a
# Processing Record 19 of the Set 9 | k
# Processing Record 20 of the Set 9 | b
# Processing Record 21 of the Set 9 | e
# Processing Record 22 of the Set 9 | p
# Processing Record 23 of the Set 9 | g
# Processing Record 24 of the Set 9 | r
# Processing Record 25 of the Set 9 | k
# City not found. Skipping...
# Processing Record 26 of the Set 9 | y
# Processing Record 27 of the Set 9 | g
# Processing Record 28 of the Set 9 | g
# Processing Record 29 of the Set 9 | k
# Processing Record 30 of the Set 9 | p
# Processing Record 31 of the Set 9 | g
# Processing Record 32 of the Set 9 | c
# Processing Record 33 of the Set 9 | c
# Processing Record 34 of the Set 9 | b
# Processing Record 35 of the Set 9 | h
# Processing Record 36 of the Set 9 | p
# Processing Record 37 of the Set 9 | v
# Processing Record 38 of the Set 9 | b
# City not found. Skipping...
# Processing Record 39 of the Set 9 | p
# Processing Record 40 of the Set 9 | c
# Processing Record 41 of the Set 9 | l
# Processing Record 42 of the Set 9 | l
# Processing Record 43 of the Set 9 | m
# Processing Record 44 of the Set 9 | k
# Processing Record 45 of the Set 9 | d
# Processing Record 46 of the Set 9 | h
# Processing Record 47 of the Set 9 | h
# Processing Record 48 of the Set 9 | p
# Processing Record 49 of the Set 9 | s
# Processing Record 50 of the Set 9 | t
# Processing Record 1 of the Set 10 | i
# Processing Record 2 of the Set 10 | d
# Processing Record 3 of the Set 10 | a
# Processing Record 4 of the Set 10 | p
# Processing Record 5 of the Set 10 | a
# Processing Record 6 of the Set 10 | k
# Processing Record 7 of the Set 10 | q
# Processing Record 8 of the Set 10 | d
# Processing Record 9 of the Set 10 | c
# Processing Record 10 of the Set 10 | p
# Processing Record 11 of the Set 10 | b
# Processing Record 12 of the Set 10 | b
# Processing Record 13 of the Set 10 | a
# Processing Record 14 of the Set 10 | g
# Processing Record 15 of the Set 10 | b
# Processing Record 16 of the Set 10 | m
# Processing Record 17 of the Set 10 | d
# Processing Record 18 of the Set 10 | n
# City not found. Skipping...
# Processing Record 19 of the Set 10 | r
# Processing Record 20 of the Set 10 | k
# Processing Record 21 of the Set 10 | s
# Processing Record 22 of the Set 10 | h
# Processing Record 23 of the Set 10 | f
# Processing Record 24 of the Set 10 | n
# Processing Record 25 of the Set 10 | b
# Processing Record 26 of the Set 10 | s
# Processing Record 27 of the Set 10 | j
# City not found. Skipping...
# Processing Record 28 of the Set 10 | s
# Processing Record 29 of the Set 10 | t
# Processing Record 30 of the Set 10 | w
# Processing Record 31 of the Set 10 | k
# Processing Record 32 of the Set 10 | s
# Processing Record 33 of the Set 10 | s
# Processing Record 34 of the Set 10 | e
# Processing Record 35 of the Set 10 | c
# City not found. Skipping...
# Processing Record 36 of the Set 10 | c
# Processing Record 37 of the Set 10 | n
# Processing Record 38 of the Set 10 | m
# Processing Record 39 of the Set 10 | h
# Processing Record 40 of the Set 10 | s
# Processing Record 41 of the Set 10 | m
# Processing Record 42 of the Set 10 | s
# Processing Record 43 of the Set 10 | c
# Processing Record 44 of the Set 10 | p
# Processing Record 45 of the Set 10 | s
# Processing Record 46 of the Set 10 | h
# Processing Record 47 of the Set 10 | s
# Processing Record 48 of the Set 10 | k
# Processing Record 49 of the Set 10 | t
# Processing Record 50 of the Set 10 | m
# Processing Record 1 of the Set 11 | t
# Processing Record 2 of the Set 11 | s
# Processing Record 3 of the Set 11 | s
# Processing Record 4 of the Set 11 | i
# Processing Record 5 of the Set 11 | m
# Processing Record 6 of the Set 11 | s
# Processing Record 7 of the Set 11 | h
# Processing Record 8 of the Set 11 | g
# Processing Record 9 of the Set 11 | n
# Processing Record 10 of the Set 11 | p
# Processing Record 11 of the Set 11 | l
# Processing Record 12 of the Set 11 | a
# Processing Record 13 of the Set 11 | p
# Processing Record 14 of the Set 11 | a
# Processing Record 15 of the Set 11 | n
# Processing Record 16 of the Set 11 | m
# Processing Record 17 of the Set 11 | m
# Processing Record 18 of the Set 11 | e
# Processing Record 19 of the Set 11 | c
# Processing Record 20 of the Set 11 | u
# Processing Record 21 of the Set 11 | m
# Processing Record 22 of the Set 11 | t
# Processing Record 23 of the Set 11 | c
# Processing Record 24 of the Set 11 | m
# Processing Record 25 of the Set 11 | m
# Processing Record 26 of the Set 11 | v
# Processing Record 27 of the Set 11 | a
# Processing Record 28 of the Set 11 | q
# Processing Record 29 of the Set 11 | o
# City not found. Skipping...
# Processing Record 30 of the Set 11 | b
# Processing Record 31 of the Set 11 | n
# Processing Record 32 of the Set 11 | c
# Processing Record 33 of the Set 11 | k
# Processing Record 34 of the Set 11 | t
# Processing Record 35 of the Set 11 | n
# Processing Record 36 of the Set 11 | d
# Processing Record 37 of the Set 11 | u
# Processing Record 38 of the Set 11 | x
# Processing Record 39 of the Set 11 | r
# Processing Record 40 of the Set 11 | a
# Processing Record 41 of the Set 11 | b
# Processing Record 42 of the Set 11 | m
# City not found. Skipping...
# Processing Record 43 of the Set 11 | s
# Processing Record 44 of the Set 11 | a
# Processing Record 45 of the Set 11 | t
# Processing Record 46 of the Set 11 | d
# Processing Record 47 of the Set 11 | b
# Processing Record 48 of the Set 11 | c
# Processing Record 49 of the Set 11 | g
# Processing Record 50 of the Set 11 | k
# Processing Record 1 of the Set 12 | a
# Processing Record 2 of the Set 12 | w
# Processing Record 3 of the Set 12 | w
# City not found. Skipping...
# Processing Record 4 of the Set 12 | y
# Processing Record 5 of the Set 12 | t
# Processing Record 6 of the Set 12 | p
# Processing Record 7 of the Set 12 | g
# City not found. Skipping...
# Processing Record 8 of the Set 12 | w
# Processing Record 9 of the Set 12 | b
# Processing Record 10 of the Set 12 | b
# Processing Record 11 of the Set 12 | v
# Processing Record 12 of the Set 12 | m
# Processing Record 13 of the Set 12 | b
# Processing Record 14 of the Set 12 | s
# Processing Record 15 of the Set 12 | k
# Processing Record 16 of the Set 12 | d
# Processing Record 17 of the Set 12 | b
# Processing Record 18 of the Set 12 | n
# Processing Record 19 of the Set 12 | c
# Processing Record 20 of the Set 12 | y
# Processing Record 21 of the Set 12 | s
# Processing Record 22 of the Set 12 | c
# Processing Record 23 of the Set 12 | k
# City not found. Skipping...
# Processing Record 24 of the Set 12 | m
# Processing Record 25 of the Set 12 | u
# Processing Record 26 of the Set 12 | a
# Processing Record 27 of the Set 12 | r
# Processing Record 28 of the Set 12 | v
# Processing Record 29 of the Set 12 | a
# Processing Record 30 of the Set 12 | s
# Processing Record 31 of the Set 12 | g
# Processing Record 32 of the Set 12 | n
# Processing Record 33 of the Set 12 | p
# Processing Record 34 of the Set 12 | i
# Processing Record 35 of the Set 12 | v
# Processing Record 36 of the Set 12 | s
# Processing Record 37 of the Set 12 | m
# Processing Record 38 of the Set 12 | s
# City not found. Skipping...
# Processing Record 39 of the Set 12 | g
# Processing Record 40 of the Set 12 | c
# Processing Record 41 of the Set 12 | d
# Processing Record 42 of the Set 12 | r
# Processing Record 43 of the Set 12 | s
# Processing Record 44 of the Set 12 | c
# Processing Record 45 of the Set 12 | s
# Processing Record 46 of the Set 12 | s
# Processing Record 47 of the Set 12 | a
# Processing Record 48 of the Set 12 | l
# Processing Record 49 of the Set 12 | m
# Processing Record 50 of the Set 12 | u
# Processing Record 1 of the Set 13 | l
# Processing Record 2 of the Set 13 | d
# Processing Record 3 of the Set 13 | c
# Processing Record 4 of the Set 13 | w
# Processing Record 5 of the Set 13 | b
# City not found. Skipping...
# Processing Record 6 of the Set 13 | d
# Processing Record 7 of the Set 13 | k
# Processing Record 8 of the Set 13 | t
# Processing Record 9 of the Set 13 | k
# Processing Record 10 of the Set 13 | f
# Processing Record 11 of the Set 13 | s
# City not found. Skipping...
# Processing Record 12 of the Set 13 | b
# Processing Record 13 of the Set 13 | b
# Processing Record 14 of the Set 13 | p
# Processing Record 15 of the Set 13 | t
# Processing Record 16 of the Set 13 | b
# Processing Record 17 of the Set 13 | m
# Processing Record 18 of the Set 13 | e
# Processing Record 19 of the Set 13 | m
# Processing Record 20 of the Set 13 | k
# City not found. Skipping...
# Processing Record 21 of the Set 13 | k
# Processing Record 22 of the Set 13 | h
# Processing Record 23 of the Set 13 | l
# Processing Record 24 of the Set 13 | o
# Processing Record 25 of the Set 13 | m
# Processing Record 26 of the Set 13 | m
# Processing Record 27 of the Set 13 | y
# Processing Record 28 of the Set 13 | j
# Processing Record 29 of the Set 13 | g
# Processing Record 30 of the Set 13 | a
# Processing Record 31 of the Set 13 | t
# Processing Record 32 of the Set 13 | j
# Processing Record 33 of the Set 13 | s
# Processing Record 34 of the Set 13 | p
# Processing Record 35 of the Set 13 | n
# Processing Record 36 of the Set 13 | a
# City not found. Skipping...
# Processing Record 37 of the Set 13 | b
# Processing Record 38 of the Set 13 | p
# Processing Record 39 of the Set 13 | p
# Processing Record 40 of the Set 13 | w
# Processing Record 41 of the Set 13 | g
# Processing Record 42 of the Set 13 | r
# Processing Record 43 of the Set 13 | s
# Processing Record 44 of the Set 13 | c
# Processing Record 45 of the Set 13 | z
# Processing Record 46 of the Set 13 | m
# Processing Record 47 of the Set 13 | s
# Processing Record 48 of the Set 13 | g
# Processing Record 49 of the Set 13 | c
# Processing Record 50 of the Set 13 | k
# Processing Record 1 of the Set 14 | s
# Processing Record 2 of the Set 14 | a
# Processing Record 3 of the Set 14 | d
# Processing Record 4 of the Set 14 | m
# Processing Record 5 of the Set 14 | d
# Processing Record 6 of the Set 14 | g
# Processing Record 7 of the Set 14 | b
# Processing Record 8 of the Set 14 | o
# Processing Record 9 of the Set 14 | k
# City not found. Skipping...
# Processing Record 10 of the Set 14 | y
# Processing Record 11 of the Set 14 | k
# Processing Record 12 of the Set 14 | m
# City not found. Skipping...
# Processing Record 13 of the Set 14 | s
# Processing Record 14 of the Set 14 | p
# Processing Record 15 of the Set 14 | p
# Processing Record 16 of the Set 14 | b
# Processing Record 17 of the Set 14 | k
# Processing Record 18 of the Set 14 | e
# Processing Record 19 of the Set 14 | n
# Processing Record 20 of the Set 14 | t
# Processing Record 21 of the Set 14 | b
# Processing Record 22 of the Set 14 | b
# Processing Record 23 of the Set 14 | b
# Processing Record 24 of the Set 14 | a
# Processing Record 25 of the Set 14 | d
# Processing Record 26 of the Set 14 | c
# Processing Record 27 of the Set 14 | s
# Processing Record 28 of the Set 14 | v
# Processing Record 29 of the Set 14 | g
# Processing Record 30 of the Set 14 | k
# Processing Record 31 of the Set 14 | c
# Processing Record 32 of the Set 14 | j
# City not found. Skipping...
# Processing Record 33 of the Set 14 | h
# Processing Record 34 of the Set 14 | s
# Processing Record 35 of the Set 14 | y
# City not found. Skipping...
# Processing Record 36 of the Set 14 | m
# Processing Record 37 of the Set 14 | a
# Processing Record 38 of the Set 14 | e
# Processing Record 39 of the Set 14 | t
# Processing Record 40 of the Set 14 | d
# Processing Record 41 of the Set 14 | m
# Processing Record 42 of the Set 14 | n
# Processing Record 43 of the Set 14 | s
# Processing Record 44 of the Set 14 | m
# Processing Record 45 of the Set 14 | p
# Processing Record 46 of the Set 14 | k
# Processing Record 47 of the Set 14 | n
# Processing Record 48 of the Set 14 | b
# Processing Record 49 of the Set 14 | k
# City not found. Skipping...
# Processing Record 50 of the Set 14 | s
# Processing Record 1 of the Set 15 | i
# Processing Record 2 of the Set 15 | c
# Processing Record 3 of the Set 15 | b
# Processing Record 4 of the Set 15 | c
# Processing Record 5 of the Set 15 | w
# Processing Record 6 of the Set 15 | s
# Processing Record 7 of the Set 15 | l
# Processing Record 8 of the Set 15 | k
# City not found. Skipping...
# Processing Record 9 of the Set 15 | o
# Processing Record 10 of the Set 15 | m
# Processing Record 11 of the Set 15 | p
# Processing Record 12 of the Set 15 | k
# Processing Record 13 of the Set 15 | s
# Processing Record 14 of the Set 15 | z
# Processing Record 15 of the Set 15 | d
# City not found. Skipping...
# Processing Record 16 of the Set 15 | s
# Processing Record 17 of the Set 15 | m
# Processing Record 18 of the Set 15 | t
# Processing Record 19 of the Set 15 | o
# Processing Record 20 of the Set 15 | r
# Processing Record 21 of the Set 15 | p
# Processing Record 22 of the Set 15 | f
# Processing Record 23 of the Set 15 | b
# City not found. Skipping...
# Processing Record 24 of the Set 15 | y
# Processing Record 25 of the Set 15 | l
# Processing Record 26 of the Set 15 | m
# Processing Record 27 of the Set 15 | s
# Processing Record 28 of the Set 15 | m
# Processing Record 29 of the Set 15 | h
# Processing Record 30 of the Set 15 | w
# Processing Record 31 of the Set 15 | i
# Processing Record 32 of the Set 15 | m
# Processing Record 33 of the Set 15 | f
# Processing Record 34 of the Set 15 | s
# Processing Record 35 of the Set 15 | s
# Processing Record 36 of the Set 15 | m
# Processing Record 37 of the Set 15 | m
# Processing Record 38 of the Set 15 | l
# Processing Record 39 of the Set 15 | n
# Processing Record 40 of the Set 15 | m
# City not found. Skipping...
# Processing Record 41 of the Set 15 | m
# Processing Record 42 of the Set 15 | h
# Processing Record 43 of the Set 15 | p
# Processing Record 44 of the Set 15 | t
# Processing Record 45 of the Set 15 | f
# Processing Record 46 of the Set 15 | s
# Processing Record 47 of the Set 15 | r
# Processing Record 48 of the Set 15 | b
# Processing Record 49 of the Set 15 | t
# City not found. Skipping...
# Processing Record 50 of the Set 15 | m
# Processing Record 1 of the Set 16 | s
# Processing Record 2 of the Set 16 | b
# City not found. Skipping...
# Processing Record 3 of the Set 16 | c
# Processing Record 4 of the Set 16 | a
# Processing Record 5 of the Set 16 | p
# Processing Record 6 of the Set 16 | b
# Processing Record 7 of the Set 16 | b
# Processing Record 8 of the Set 16 | f
# Processing Record 9 of the Set 16 | u
# Processing Record 10 of the Set 16 | k
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the sum of cities in the city_data array.
len(city_data)
# Out:
# 701

# %%
# Convert to a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Alfred -33.5906   26.8910     65.73        83          98
# 1         Rikitea -23.1203 -134.9692     77.86        71          45
# 2    Puerto Ayora  -0.7393  -90.3518     77.56        91          35
# 3    Saint-Pierre -21.3393   55.4781     78.48        78         100
# 4          Bethel  41.3712  -73.4140     40.50        67           0
# 5  Ribeira Grande  38.5167  -28.7000     57.27        66          36
# 6         Kahului  20.8947 -156.4700     83.46        73           0
# 7           Vaini -21.2000 -175.2000     81.61        79          77
# 8          Avarua -21.2078 -159.7750     86.05        74          40
# 9         Mataura -46.1927  168.8643     50.65        98         100
#
#    Wind Speed Country Current Description
# 0        7.83      ZA     overcast clouds
# 1        5.57      PF    scattered clouds
# 2        1.99      EC    scattered clouds
# 3        5.75      RE     overcast clouds
# 4        0.00      US           clear sky
# 5        2.28      PT    scattered clouds
# 6       18.41      US           clear sky
# 7       19.62      TO       moderate rain
# 8       19.57      CK    scattered clouds
# 9        6.87      NZ     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Port Alfred      ZA -33.5906   26.8910     65.73        83          98
# 1         Rikitea      PF -23.1203 -134.9692     77.86        71          45
# 2    Puerto Ayora      EC  -0.7393  -90.3518     77.56        91          35
# 3    Saint-Pierre      RE -21.3393   55.4781     78.48        78         100
# 4          Bethel      US  41.3712  -73.4140     40.50        67           0
# ..            ...     ...      ...       ...       ...       ...         ...
# 696        Beyneu      KZ  45.3167   55.2000     42.06        72         100
# 697        Bozhou      CN  33.8772  115.7703     41.61        39         100
# 698        Falciu      RO  46.2961   28.1408     41.14        84          40
# 699        Urusha      RU  54.0500  122.9000      6.19        68          86
# 700       Klyuchi      RU  52.2667   79.1667     10.60        91         100
#
#      Wind Speed Current Description
# 0          7.83     overcast clouds
# 1          5.57    scattered clouds
# 2          1.99    scattered clouds
# 3          5.75     overcast clouds
# 4          0.00           clear sky
# ..          ...                 ...
# 696        6.51     overcast clouds
# 697        8.43     overcast clouds
# 698        4.72    scattered clouds
# 699        3.04     overcast clouds
# 700        7.09     overcast clouds
#
# [701 rows x 9 columns]

# %%
# Create output file.
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
